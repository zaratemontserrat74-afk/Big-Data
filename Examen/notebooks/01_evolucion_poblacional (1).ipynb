# %% [markdown]
# **Actividad 1 y 2**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/annual-population-growth/annual-population-growth.csv")

# %% [markdown]
# Preguntas:
# 1. ¿Cuántas filas y columnas tiene el dataset? R: 38400 filas y 5 columnas
# 2. ¿Qué tipo de datos contiene la variable Year? R: Contiene el tipo de dato INT
# 3. ¿Existen valores faltantes? R: Si existen valores faltantes en las columnas Code,Annual change in population y Annual population change (Projected)
# 4. ¿Cuántas entidades diferentes contiene el dataset? R:Contiene 256 Entidades unicas

# %% [markdown]
# 1. ¿Quién produjo originalmente los datos? R:Our World in Data
# 2. ¿Qué organización los procesa para su utilización en Our World in Data? R: La United Nations
# 3. ¿Qué representa la variable que analizarás? R: La evolución poblacional

# %%
df.head()
# Out:
#         Entity Code  Year  Annual change in population  \
# 0  Afghanistan  AFG  1951                     103163.0
# 1  Afghanistan  AFG  1952                     108441.0
# 2  Afghanistan  AFG  1953                     108919.0
# 3  Afghanistan  AFG  1954                     111251.0
# 4  Afghanistan  AFG  1955                     119027.0
#
#    Annual population change (Projected)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df_year = df[["Year"]]
print(df_year.head())
# Out:
#    Year
# 0  1951
# 1  1952
# 2  1953
# 3  1954
# 4  1955

# %%
df.shape
# Out:
# (38400, 5)

# %%
df.columns.tolist()
# Out:
# ['Entity',
#  'Code',
#  'Year',
#  'Annual change in population',
#  'Annual population change (Projected)']

# %%
df.dtypes
# Out:
# Entity                                      str
# Code                                        str
# Year                                      int64
# Annual change in population             float64
# Annual population change (Projected)    float64
# dtype: object

# %%
df.describe()
# Out:
#                Year  Annual change in population  \
# count  38400.000000                 1.868800e+04
# mean    2025.500000                 2.063019e+06
# std       43.300872                 9.440859e+06
# min     1951.000000                -3.315935e+06
# 25%     1988.000000                 1.781000e+03
# 50%     2025.500000                 4.689800e+04
# 75%     2063.000000                 3.021128e+05
# max     2100.000000                 9.337137e+07
#
#        Annual population change (Projected)
# count                          1.971200e+04
# mean                           8.375481e+05
# std                            5.816745e+06
# min                           -2.291035e+07
# 25%                           -9.742750e+03
# 50%                            9.350000e+01
# 75%                            1.411160e+05
# max                            7.206736e+07

# %%
df.isnull().sum()
# Out:
# Entity                                      0
# Code                                     1200
# Year                                        0
# Annual change in population             19712
# Annual population change (Projected)    18688
# dtype: int64

# %%
df["Entity"].nunique()
# Out:
# 256

# %% [markdown]
# **Actividad 3**

# %%
df_2005 = df[(df["Year"] >= 2005) & (df["Year"] <= 2023) & (df["Entity"] == "Sweden")]
cambio_anual = df_2005["Annual change in population"]

# %%
media = cambio_anual.mean()
print("Media", media)
# Out:
# Media 81983.57894736843

# %%
mediana = cambio_anual.median()
print("Mediana", mediana)
# Out:
# Mediana 74562.0

# %%
varianza = cambio_anual.var()
print("Varianza", varianza)
# Out:
# Varianza 635094171.8128656

# %%
desviacion_estandar = cambio_anual.std()
print("Desviación Estándar", desviacion_estandar)
# Out:
# Desviación Estándar 25201.074814635696

# %%
minimo = cambio_anual.min()
print("Mínimo", minimo)
# Out:
# Mínimo 35966.0

# %%
maximo = cambio_anual.max()
print("Máximo", maximo)
# Out:
# Máximo 134583.0

# %%
entidad_min = df.loc[df["Annual change in population"].idxmin(), "Entity"]
entidad_max = df.loc[df["Annual change in population"].idxmax(), "Entity"]
print("Mas bajo:", entidad_min)
print("Mas alto:", entidad_max)
# Out:
# Mas bajo: Ukraine
# Mas alto: World

# %% [markdown]
# 1. ¿Cuál es el valor de la media? R: 81983.57
# 2. ¿Cuál es el valor de la mediana? R: 74562
# 3. ¿Cuál es el valor de la desviación estándar? R: 25201.07
# 4. ¿Qué entidad presenta el valor mínimo y cuál el máximo? R: El mas bajo Ukrania y el mas alto World

# %% [markdown]
# **Actividad 4**

# %%
import sys
print("Python", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# Python 3.14.7 (tags/v3.14.7:823f032, Aug  5 2026, 10:51:32) [MSC v.1944 64 bit (AMD64)]
# Pandas: 3.0.5
# NumPy: 2.5.3

# %%
df.loc[10000]
# Out:
# Entity                                  Equatorial Guinea
# Code                                                  GNQ
# Year                                                 2051
# Annual change in population                           NaN
# Annual population change (Projected)              46407.0
# Name: 10000, dtype: object

# %%
df.loc[10000,["Entity", "Year", "Annual change in population"]]
# Out:
# Entity                         Equatorial Guinea
# Year                                        2051
# Annual change in population                  NaN
# Name: 10000, dtype: object

# %% [markdown]
# Los datos utilizados en esta práctica provienen de **Our World in Data (OWID)**.
#
#
# La fuente original es **United Nations, World Population Prospects (2024)**.
#
#
# **Cita**
#
# UN, World Population Prospects (2024) – processed by Our World in Data. “Annual change in population – UN WPP” [dataset]. United Nations, “World Population Prospects”; United Nations, “World Population Prospects - Inter im Update” [original data].
